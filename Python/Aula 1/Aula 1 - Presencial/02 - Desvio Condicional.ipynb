# %%
# if e else
idade = 10
if idade >= 0 and idade <= 5:
  print("A idade está entre 0 e 5")
elif idade > 5 and idade <= 7:
  print("Outra condição .....")
else:
  print("A idade é diferente do intervalo entre 0 e 5")
# Out:
# A idade é diferente do intervalo entre 0 e 5
