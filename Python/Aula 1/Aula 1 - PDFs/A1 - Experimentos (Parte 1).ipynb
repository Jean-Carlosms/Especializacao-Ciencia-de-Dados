# %%
# O comando abaixo serve para imprimir na tela uma frase...

'''
  Isso 
  é 
  um comentário
  em várias linhas...
'''

print('Um texto qualquer...')
# Out:
# Um texto qualquer...

# %%
# nome = ""

nome = "Adriano"
idade = 30

print("Olá, o meu nome é", nome)
print("Olá, o meu nome é" +  nome)
print("Olá meu nome é {0} e a idade é de {1}".format(idade, nome))
print(f"Olá meu nome é {nome} e a idade é de {idade}")
# Out:
# Olá, o meu nome é Adriano
# Olá, o meu nome éAdriano
# Olá meu nome é 30 e a idade é de Adriano
# Olá meu nome é Adriano e a idade é de 30

# %%
# Descobrindo o tipo de uma variável e trabalhando com números:

import math

nome = "Adriano"
idade = '30'

raiz_quadrada = math.sqrt(9)
print(raiz_quadrada)

idade_convertida = int(idade)

type(idade_convertida)
# Out:
# 3.0
# int

# %%
frase = "Estou na minha primeira aula de Python na Facens."

nova_frase = frase.replace('primeira', 'segunda')

print(nova_frase)

print(nova_frase[0:12])
# Out:
# Estou na minha segunda aula de Python na Facens.
# Estou na min

# %%
print('Informe o seu nome: ')
nome = input()

print(f'O nome escolhido é: {nome}')
# Out:
# Informe o seu nome:
# Chimbinha
# O nome escolhido é: Chimbinha
