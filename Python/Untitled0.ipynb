# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('/content/Novo Documento de Texto (3).txt')
# Out:
#     eight9fhstbssrplmdlncmmqqnklb39ninejz
# 0                                three656
# 1               ppjvndvknbtpfsncplmhhrlh5
# 2             7fjqhrhsevenlbtwoninevnmct2
# 3                            qjnbpfrztwo1
# 4                       plggqjthree49four
# ..                                    ...
# 994                      five8dvdjqfmpnh3
# 995                            scjjr4twoh
# 996                           nine35gzmlt
# 997                     5sixfour2qxsqkpnq
# 998                           kdkjqdkvgs2
#
# [999 rows x 1 columns]

# %%
numeros = [x for x in lista if isinstance(x, (int, float))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-acb27a9ef62c> in <cell line: 1>()
# ----> 1 pd[pd == int]
#
# TypeError: 'module' object is not subscriptable
