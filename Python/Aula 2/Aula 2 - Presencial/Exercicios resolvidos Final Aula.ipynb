# %%
#Exercicio 6
#criar função definidados no enunciado
#nome da função growth_rate e deve ter 2 parametros population a e population b

population_a = 90
population_b = 20

def growth_rate(population_a, population_b):

  if type(population_a) != int or type(population_b) != int:
    print("Invalid argument")
  elif population_a < 0 or population_b < 0:
    print("Invalid argument")

  else:

    years = 0
    while population_a < population_b:

      population_a += (population_a * 0.03)
      population_b += (population_b * 0.015)
      years += 1

  return years
  print(f"em {years} na população A passará a População B")
