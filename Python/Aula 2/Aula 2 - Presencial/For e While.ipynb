# %%
#For e While

texto = "alguma coisa"

for letra in texto:
  print(letra)
# Out:
# a
# l
# g
# u
# m
# a
#
# c
# o
# i
# s
# a

# %%
count = 5

while count >= 0:
  print(count)

  count -= 1
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
numeros = [1, 2, 3, 4, 5, 6]

for n in numeros:
  if n % 2 == 0:
    print(n)
# Out:
# 2
# 4
# 6

# %%
#list comparation
pares = [n for n in numeros if n % 2 == 0]
print(pares)
# Out:
# [2, 4, 6]
