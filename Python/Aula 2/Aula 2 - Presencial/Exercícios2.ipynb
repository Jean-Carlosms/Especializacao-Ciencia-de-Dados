# %%
#variável de entrada
numero= 7
inicio= 1
inicio = int(inicio)
#verificação se o número é inteiro e positivo
if numero >=0 and numero // 1 == numero:
  divizivel = 1

while divizivel <= numero:
  qualquer= numero/divizivel
  divizivel += 1
  print("É Primo") if qualquer == numero else print("Não é primo")

else:
  print("Número Inválido!")
# Out:
# É Primo
# Não é primo
# Não é primo
# Não é primo
# Não é primo
# Não é primo
# Não é primo
# Número Inválido!
