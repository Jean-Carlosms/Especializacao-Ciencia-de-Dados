# %%
# Listas
exemplo = ["Adriano", "Juliana", "Carlos", "Ximbinha", 2, 2.3, True]

type(exemplo[1])

print(exemplo)

exemplo.append("Facens")

print(exemplo)

exemplo.pop(-1)

print(exemplo)

del exemplo[0]

print(exemplo)

exemplo[5] = "Johannes me dê um aumento"

print(exemplo)
# Out:
# ['Adriano', 'Juliana', 'Carlos', 'Ximbinha', 2, 2.3, True]
# ['Adriano', 'Juliana', 'Carlos', 'Ximbinha', 2, 2.3, True, 'Facens']
# ['Adriano', 'Juliana', 'Carlos', 'Ximbinha', 2, 2.3, True]
# ['Juliana', 'Carlos', 'Ximbinha', 2, 2.3, True]
# ['Juliana', 'Carlos', 'Ximbinha', 2, 2.3, 'Johannes me dê um aumento']

# %%
exemplo_02= [exemplo
             [1, 2, 3, [99, 100, 0]],
             "Adriano",
             [[], [], [23,]]
             ]

# %%
#Tuplas:
#Obs  Listas = mutaveis "sempre mudam", tuplas = imutaveis "Estáticas"
#Obs2 Tuplas finaliza com vírgula
exemplo_tupla = (1, 2, 3,)
type(exemplo_tupla)

lista_alunos = [("Adriano", "adriano@facens.br",),
                ("Juliana", "juliana@facens.br",),
                ]

print(len(lista_alunos[0]))
# Out:
# 2

# %%
#Dicionário
d = {
    "nome":"Jean",
    "idade": 31,
}

d["nome"]
#retornas os objetos
d.keys()
#retorna os valores dos objetos
d.values()


bd_alunos = [
    {
        "nome":"Adriano",
        "idade":31,
        "interesses":["carros", "informática"]
    },
    {
        "nome": "Juliana",
        "idade":27
    }
]

bd_alunos[0]["interesses"][1]
# Out:
# 'informática'
