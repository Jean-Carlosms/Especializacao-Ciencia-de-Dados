# %%
#Exercício 1

l = [8, 11, 20, 31, 40, 51, 60]
impar=[]
par=[]

par.append(l[0]) if l[0] % 2 == 0  else impar.append(l[0])
par.append(l[1]) if l[1] % 2 == 0  else impar.append(l[1])
par.append(l[2]) if l[2] % 2 == 0  else impar.append(l[2])
par.append(l[3]) if l[3] % 2 == 0  else impar.append(l[3])
par.append(l[4]) if l[4] % 2 == 0  else impar.append(l[4])
par.append(l[5]) if l[5] % 2 == 0  else impar.append(l[5])

tupla = (impar, par)
print(tupla)
# Out:
# ([11, 31, 51], [8, 20, 40])

# %%
#Exercício 2
nome= input("Escreva o seu nome: ")
idade= input("Escreva a sua idade: ")
idade = int(idade)
interesses_1= input("Escreva o seu primeiro interesse: ")
interesses_2= input("Escreva o seu segundo interesse: ")

dicionario ={
    "nome": nome,
    "idade": idade,
    "Interesses": [interesses_1, interesses_2],
     "Informações Adicionais":{
        "Quantidade de letras do nome": (len(nome)),
        "Idade ao quadrado": pow(idade, 2),
        "Lista dos numeros da idade": list(str(idade)),
     }

}

print(dicionario)
# Out:
# Escreva o seu nome: Jena
# Escreva a sua idade: 31
# Escreva o seu primeiro interesse: f
# Escreva o seu segundo interesse: a
# {'nome': 'Jena', 'idade': 31, 'Interesses': ['f', 'a'], 'Informações Adicionais': {'Quantidade de letras do nome': 4, 'Idade ao quadrado': 961, 'Lista dos numeros da idade': ['3', '1']}}
