# %%
example = ['Adriano', 4, 4.5, True]

print(type(example[3]))
# Out:
# <class 'bool'>

# %%
del example[0]

# %%
print(example)
# Out:
# [4, 4.5, True]

# %%
example = [1, 2, 3, 4, 5, 6]
print(example)

example = example[0:-1]
print(example)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5]

# %%
example.pop(-1)
# Out:
# 5

# %%
print(example)
# Out:
# [1, 2, 3, 4]

# %%
example.reverse()

# %%
print(example)
# Out:
# [4, 3, 2, 1]

# %%
example[0] = 80
print(example)
# Out:
# [80, 3, 2, 1]

# %%
a = 3
print(id(a))

a = 5
print(id(a))
# Out:
# 94246467578432
# 94246467578496

# %%
exemplo_dicionario = {
    'nome': 'Adriano',
    'idade': 30,
    'interesses': ['Motos', 'Informática'],
    'contatos': {
        'celular': 'XXXXX',
        'email': 'dsjkhdasjndlskjd'
    }
 }

# %%
exemplo_dicionario.keys()
# Out:
# dict_keys(['nome', 'idade', 'interesses', 'contatos'])

# %%
exemplo_dicionario.values()
# Out:
# dict_values(['Adriano', 30, ['Motos', 'Informática'], {'celular': 'XXXXX', 'email': 'dsjkhdasjndlskjd'}])

# %%
exemplo_dicionario["nome"] = "Adriano Silva"

# %%
print(exemplo_dicionario)
# Out:
# {'nome': 'Adriano Silva', 'idade': 30, 'interesses': ['Motos', 'Informática'], 'contatos': {'celular': 'XXXXX', 'email': 'dsjkhdasjndlskjd'}}

# %%
exemplo_dicionario.pop("idade")
# Out:
# 30

# %%
print(exemplo_dicionario)
# Out:
# {'nome': 'Adriano Silva', 'interesses': ['Motos', 'Informática'], 'contatos': {'celular': 'XXXXX', 'email': 'dsjkhdasjndlskjd'}}
