# %% [markdown]
# ###### 1. Qual é a proporção aproximada de pacientes que compareceram à consulta?
# ###### 1. 80%
# ###### 2. 50%
# ###### 3. 75%
# ###### 4. 60%
# ###### 5. 70%

# %% [markdown]
# ######2. Quantas instâncias e atributos existem no dataset, respectivamente?
# #####1.12 e 100456.
# ######2. 110527 e 14.
# ######3. 100456 e 12.
# ######4. 14 e 110527.

# %% [markdown]
# ######3. Qual das colunas do dataset possui valores nulos?
# ######1. Handcap.
# ######2. Neighbourhood.
# ######3. Age.
# ######4. Nenhuma.

# %% [markdown]
# ######4. Qual é a idade média dos pacientes?
# ######1. 18
# ######2. 37
# ######3. 23
# ######4. 55

# %% [markdown]
# ######5. Em quantas localidades diferentes (Neighbourhood) os pacientes residem?
# ######1. 103
# ######2. 27
# ######3. 81
# ######4. 34

# %% [markdown]
# ######6. Comparando apenas a identificação do paciente (PatientId) com o número dos agendamentos das consultas (AppointmentID), o que podemos inferir?
# ######Você respondeu
# ######1. Pacientes com maior idade comparecem menos às consultas.
# ######2. O número de consultas realizadas em dias de semana é maior.
# ######3. Existem pacientes que realizam mais de 1 atendimento.
# ######4. A idade dos pacientes é superior a 35 anos.

# %% [markdown]
# ######7. Quantas variáveis binárias (apenas dois valores) existem no dataset?
# ######1. 10
# ######2. 14
# ######3. 2
# ######4. 7

# %% [markdown]
# ######8. Quantos valores diferentes encontramos para a variável dos SMS recebidos (SMS_received)?
# ######1. 8
# ######2. 2
# ######3. 4
# ######4. 12

# %% [markdown]
# ######9. Qual é a menor e maior idade, respectivamente, presente no dataset?
# ######1. -1 e 115
# ######2. 0 e 115
# ######3. 6 e 113
# ######4. 1 e 113

# %% [markdown]
# ######10. Qual é a proporção de pacientes que receberam o SMS e NÃO compareceram?
# ######1. 15%
# ######2. 27%
# ######3. 72%
# ######4. 50%

# %% [markdown]
# ######11. Qual região possui o maior número de consultas marcadas?
# ######1. 38
# ######2. 16
# ######3. 1
# ######4. 64
